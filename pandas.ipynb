# %% [markdown]
# # # pandas

# %%
import pandas as pd
a={"si_no":[1,2,3],"name":["hema","vishu","deepu",]}
pd.DataFrame(a)
print(a)
# Out:
# {'si_no': [1, 2, 3], 'name': ['hema', 'vishu', 'deepu']}

# %%
import pandas as pd
a=pd.read_csv("/home/hemalatha/Downloads/Iris.csv")
print(a.isnull().sum())
print(a.describe())
print(a.unique())
print(a.head())
print(a.tail())
print(a.shape())
print(a)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
import pandas as pd
a={"si_no":[1,2,3],"name":["hema","vishu","deepu",]}
print(a)
# Out:
# {'si_no': [1, 2, 3], 'name': ['hema', 'vishu', 'deepu']}

# %%
import pandas as pd
print("pandas version:",pd.__version__)
a=pd.DataFrame({"si_no":[1,2,3],"name":["hema","sheema","siri"]})
print(a)
# Out:
# pandas version: 1.5.3
#    si_no    name
# 0      1    hema
# 1      2  sheema
# 2      3    siri

# %%
import pandas as pd
a=pd.read_csv("/home/hemalatha/Downloads/Iris.csv")
print(a.isnull().sum())
print(a.describe())
print(a.head())
print(a.tail())
print(a.size())
print(a)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# ...

# %%
import pandas as pd
a=pd.DataFrame({"soprts":["cricket","volly ball","carroms","tennies","running"],"ranking":[1,6,8,9,25],"preferences":[6,8,7,1,2],"venue":["vskp","ysp","nlr","kdp","elr"]})
print(a)
x=a.to_excel("sports.xlsx")
x=a.to_csv("sports.csv")
# Out:
#        soprts  ranking  preferences venue
# 0     cricket        1            6  vskp
# 1  volly ball        6            8   ysp
# 2     carroms        8            7   nlr
# 3     tennies        9            1   kdp
# 4     running       25            2   elr

# %%
import pandas as pd
a=pd.Series(['p','q','r','s'])
b=pd.Series([100,200,300,400])
b.loc[2]
# Out:
# 300

# %%
import pandas as pd
df=pd.DataFrame({"name":["ravi","sita","kiran","hema","sheema"],"marks":[45,78,60,55,65]})
print(df)
df[df["marks"]>50]
# Out:
#      name  marks
# 0    ravi     45
# 1    sita     78
# 2   kiran     60
# 3    hema     55
# 4  sheema     65
#      name  marks
# 1    sita     78
# 2   kiran     60
# 3    hema     55
# 4  sheema     65

# %%
import pandas as pd
a=pd.Series([10,None,30,40])
print(a)
print(a.isnull())
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# 3    40.0
# dtype: float64
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
import pandas as pd
a=pd.Series([12,45,78,23,90])
print(a.mean(),a.median())
# Out:
# 49.6 45.0

# %%
import pandas as pd
s=pd.Series(["apple","banana","cherry","date"],index=['w','x','y','z'])
print(a.iloc[2:3])
print(a.tail(2))
# Out:
# 2    78
# dtype: int64
# 3    23
# 4    90
# dtype: int64
